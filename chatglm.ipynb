# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("D:\gpt\chatglm-6b-int4\ChatGLM-6B\THUMD\chatglm-6b-int4", trust_remote_code=True)
model = AutoModel.from_pretrained("D:\gpt\chatglm-6b-int4\ChatGLM-6B\THUMD\chatglm-6b-int4", trust_remote_code=True).float()
model = model.eval()
response, history = model.chat(tokenizer, "你好", history=[])
print(response)
response, history = model.chat(tokenizer, "晚上睡不着应该怎么办", history=history)
print(response)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 from transformers import AutoTokenizer, AutoModel
# ----> 2 tokenizer = AutoTokenizer.from_pretrained("D:\gpt\chatglm-6b-int4\ChatGLM-6B\THUMD\chatglm-6b-int4", trust_remote_code=True)
#       3 model = AutoModel.from_pretrained("D:\gpt\chatglm-6b-int4\ChatGLM-6B\THUMD\chatglm-6b-int4", trust_remote_code=True).float()
#       4 model = model.eval()
#
# File d:\gpt\chatglm-6b-int4\venv\lib\site-packages\transformers\models\auto\tokenization_auto.py:619, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     616     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     618 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# ...
